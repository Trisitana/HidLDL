# %%
import pandas as pd
import numpy as np
from pyldl.param import param_setting_alpha
from pyldl.algorithms import IncomLDL, WInLDL, HidLDL, LDL_DPA,LDL_LRR,SA_IIS, PT_Bayes
from pyldl.utils import load_dataset, random_missing_real

# %%
X, y = load_dataset('SJAFFE')

y_missing, mask = random_missing_real(y, missing_rate=.5)

metrics=["chebyshev", "clark", "canberra", "kl_divergence", "cosine", "intersection"]

# %%
incomldl = IncomLDL()
best_alpha, best_score = param_setting_alpha(incomldl,X,y,y_missing,mask,np.geomspace(2**-10, 2**10, num=21),100)
print(best_alpha)
print(pd.Series(best_score, index=metrics))
# Out:
# Converged in 41 iterations.
# Converged in 41 iterations.
# Converged in 42 iterations.
# Converged in 46 iterations.
# Converged in 71 iterations.
# Converged in 91 iterations.
# Converged in 99 iterations.
# Converged in 90 iterations.
# Converged in 63 iterations.
# Converged in 43 iterations.
# Converged in 30 iterations.
# Converged in 18 iterations.
# Converged in 10 iterations.
# Converged in 10 iterations.
# Converged in 10 iterations.
# Converged in 10 iterations.
# Converged in 10 iterations.
# Converged in 18 iterations.
# Converged in 39 iterations.
# Converged in 82 iterations.
# 2.0000000000000004
# chebyshev        0.115311
# clark            0.430182
# canberra         0.893980
# kl_divergence    0.198900
# cosine           0.924128
# intersection     0.848686
# dtype: float64

# %%
winldl = WInLDL()
winldl.fit(X, y_missing, mask=mask)
print(pd.Series(winldl.score(X, y), index=metrics))
# Out:
# Converged in 26 iterations.
# chebyshev        0.193832
# clark            1.095478
# canberra         2.123281
# kl_divergence    3.293408
# cosine           0.822328
# intersection     0.712397
# dtype: float64

# %%
HidLDL = HidLDL()
best_alpha, best_score = param_setting_alpha(HidLDL,X,y,y_missing,mask,np.geomspace(2**-10, 2**10, num=21),100)
print(best_alpha)
print(pd.Series(best_score, index=metrics))
# Out:
# Converged in 90 iterations.
# Converged in 90 iterations.
# Converged in 90 iterations.
# Converged in 89 iterations.
# Converged in 89 iterations.
# Converged in 89 iterations.
# Converged in 89 iterations.
# Converged in 89 iterations.
# Converged in 87 iterations.
# Converged in 84 iterations.
# Converged in 74 iterations.
# Converged in 66 iterations.
# Converged in 58 iterations.
# Converged in 96 iterations.
# 7.999999999999995
# chebyshev        0.080723
# clark            0.298232
# canberra         0.619777
# kl_divergence    0.038177
# cosine           0.964575
# intersection     0.896677
# dtype: float64

# %%
ldl_dpa = LDL_DPA()
ldl_dpa.fit(X, y_missing)
print(pd.Series(ldl_dpa.score(X, y), index=metrics))
# Out:
# chebyshev        0.260198
# clark            1.007042
# canberra         2.163626
# kl_divergence    0.424221
# cosine           0.768939
# intersection     0.658769
# dtype: float64

# %%
ldl_LRR = LDL_LRR()
ldl_LRR.fit(X, y_missing,beta=1e-2)
print(pd.Series(ldl_LRR.score(X, y), index=metrics))
# Out:
# chebyshev        0.122084
# clark            0.443291
# canberra         0.929410
# kl_divergence    0.077713
# cosine           0.926671
# intersection     0.841361
# dtype: float64

# %%
sa_IIS = SA_IIS()
sa_IIS.fit(X, y_missing)
print(pd.Series(sa_IIS.score(X, y), index=metrics))
# Out:
# chebyshev        0.119716
# clark            0.446726
# canberra         0.931454
# kl_divergence    0.077099
# cosine           0.927142
# intersection     0.840869
# dtype: float64

# %%
pt_bayes = PT_Bayes()
pt_bayes.fit(X, y_missing)
print(pd.Series(pt_bayes.score(X, y), index=metrics))
# Out:
# chebyshev        0.132611
# clark            0.495715
# canberra         1.032132
# kl_divergence    0.106806
# cosine           0.903518
# intersection     0.820767
# dtype: float64
